# %% [markdown]
# <a href="https://colab.research.google.com/github/nvasin/StockAdvisor/blob/main/EDAs/GAZP_EDA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ticker = 'GAZP'
data = pd.read_csv(f'{ticker}_moex_10m_data.csv')

# %%
# import yfinance as yf


# start_date = '2022-03-01'
# end_date = '2024-11-01'
# data = yf.download('AAPL', start_date, end_date)

# %% [markdown]
# ## Изучение структуры данных

# %%
data['Datetime'] = pd.to_datetime(data['Datetime'])
date_range = str(data['Datetime'].dt.date.min()) + ' to ' + str(data['Datetime'].dt.date.max())
date_range
# Out:
# '2021-10-01 to 2024-11-02'

# %%
data.set_index('Datetime', inplace = True)

# %%
data.head()
# Out:
#                        Open    High     Low   Close     Volume Ticker
# Datetime
# 2021-10-01 09:50:00  358.45  358.45  358.45  358.45   130460.0   GAZP
# 2021-10-01 10:00:00  358.45  360.26  357.29  359.79  4175250.0   GAZP
# 2021-10-01 10:10:00  359.79  359.90  357.70  357.75  1690270.0   GAZP
# 2021-10-01 10:20:00  357.80  358.16  357.30  358.08  1210420.0   GAZP
# 2021-10-01 10:30:00  358.08  358.26  356.22  356.50  2015490.0   GAZP

# %%
data.isnull().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# Ticker    0
# dtype: int64

# %%
data.describe()
# Out:
#                 Open           High            Low          Close  \
# count  304395.000000  304395.000000  304395.000000  304395.000000
# mean      193.922878     194.189637     193.624418     193.915700
# std        68.710825      68.869516      68.535065      68.706227
# min       110.470000     111.230000     110.000000     110.470000
# 25%       160.080000     160.200000     159.950000     160.080000
# 50%       167.300000     167.440000     167.150000     167.300000
# 75%       193.530000     193.950000     193.110000     193.540000
# max       395.060000     397.640000     395.000000     395.060000
#
#              Volume
# count  3.043950e+05
# mean   5.492106e+05
# std    1.095813e+06
# min    1.000000e+01
# 25%    1.053800e+05
# 50%    2.369800e+05
# 75%    5.680000e+05
# max    4.051728e+07

# %% [markdown]
# > Структура данных - OHLC.
#
# > Данные с временным шагом 10 минут.
#
# > За период 01.10.2021 - 02.11.2024.
#
# > Пропуски отсутствуют.

# %% [markdown]
# ## Первичная визуализация

# %%
data['Close'].plot()
plt.title(ticker)
plt.ylabel("Price")
plt.rc("figure", figsize=(25,5))
plt.show()

# %%
plt.style.use("fivethirtyeight")
plt.rcParams['lines.linewidth'] = 1
data.plot(subplots=True, figsize=(25, 25))
# Out:
# array([<Axes: xlabel='Datetime'>, <Axes: xlabel='Datetime'>,
#        <Axes: xlabel='Datetime'>, <Axes: xlabel='Datetime'>,
#        <Axes: xlabel='Datetime'>], dtype=object)

# %%
data['Close'].resample("ME").sum().plot()
plt.title('Resampled  - Month')
# Out:
# Text(0.5, 1.0, 'Resampled  - Month')

# %%
import statsmodels.api as sm


res = sm.tsa.seasonal_decompose(data['Close'].resample("W").sum())
resplot = res.plot()

# %% [markdown]
# > Сезонности нет.

# %% [markdown]
# ## Статистические характеристики

# %%
X = data['Close'].resample("W").sum()

rolmean = X.rolling(6).mean()
rolstd = X.rolling(6).std()

plt.figure(figsize=(18,6))
orig = plt.plot(X, color='red',label='Original')
mean = plt.plot(rolmean, color='black', label='Rolling Mean')
std = plt.plot(rolstd, color='green', label = 'Rolling Std')
plt.xlabel("Date")
plt.title('Rolling Mean & Standard Deviation')
plt.legend()
plt.show()

# %% [markdown]
# > Нестационарный временной ряд.

# %% [markdown]
# ## Специальные тесты TS

# %% [markdown]
# ADF

# %%
from statsmodels.tsa.stattools import adfuller


X = data['Close'].resample("W").sum().values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# print('Critical Values:')
# for key, value in result[4].items():
# 	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -4.091034
# p-value: 0.001002

# %% [markdown]
# ACF

# %%
from statsmodels.graphics.tsaplots import plot_acf


plot_acf(X)
plt.show()

# %% [markdown]
# PACF

# %%
from statsmodels.graphics.tsaplots import plot_pacf


plot_pacf(X, lags=50)
plt.show()

# %% [markdown]
# ## Дополнительно

# %%
data_2 = data.copy()

# %%
data_2['year'] = [x for x in data_2.index.year]
data_2['month'] = [x for x in data_2.index.month]
data_2 = data_2.reset_index()
data_2['week'] = data_2['Datetime'].apply(lambda x:x.week)
data_2 = data_2.set_index('Datetime')
data_2['hour'] = [x for x in data_2.index.hour]
data_2['day'] = [x for x in data_2.index.day_of_week]
data_2['day_str'] = [x.strftime('%a') for x in data_2.index]
data_2['year_month'] = [str(x.year) + '_' + str(x.month) for x in data_2.index]

# %%
import seaborn as sns


df_plot = data_2[['hour', 'day_str', 'Close']].dropna().groupby(['hour', 'day_str']).mean()[['Close']].reset_index()

plt.figure(figsize=(10,8))
sns.lineplot(data = df_plot, x='hour', y='Close', hue='day_str', legend=True)
plt.locator_params(axis='x', nbins=24)
plt.title("Seasonal Plot - Daily", fontsize=20)
plt.ylabel('Price')
plt.xlabel('Hour')
plt.legend()

# %%
data_2['year'] = [x for x in data_2.index.year]
data_2['month'] = [x for x in data_2.index.month]
data_2['year_month'] = [str(x.year) + '_' + str(x.month) for x in data_2.index]

df_plot = data_2[data_2['year'] >= 2017].reset_index().sort_values(by='Datetime').set_index('Datetime')
plt.title(f'Boxplot Year Month Distribution');
plt.xticks(rotation=90)
plt.xlabel('Year Month')
plt.ylabel('MW')

sns.boxplot(x='year_month', y='Close', data=df_plot)
plt.ylabel('Price')
plt.xlabel('Year Month')
# Out:
# Text(0.5, 0, 'Year Month')
