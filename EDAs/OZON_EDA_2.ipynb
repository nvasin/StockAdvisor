# %% [markdown]
# <a href="https://colab.research.google.com/github/nvasin/StockAdvisor/blob/main/EDAs/OZON_EDA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ticker = 'OZON'
data = pd.read_csv(f'{ticker}_moex_10m_data.csv')

# %%
# import yfinance as yf


# start_date = '2022-03-01'
# end_date = '2024-11-01'
# data = yf.download('AAPL', start_date, end_date)

# %% [markdown]
# ## Изучение структуры данных

# %%
data['Datetime'] = pd.to_datetime(data['Datetime'])
date_range = str(data['Datetime'].dt.date.min()) + ' to ' + str(data['Datetime'].dt.date.max())
date_range
# Out:
# '2021-10-01 to 2024-11-02'

# %%
data.set_index('Datetime', inplace = True)

# %%
data.head()
# Out:
#                        Open    High     Low   Close  Volume Ticker
# Datetime
# 2021-10-01 09:50:00  3660.0  3660.0  3660.0  3660.0    26.0   OZON
# 2021-10-01 10:00:00  3660.0  3665.0  3633.0  3642.0  2609.0   OZON
# 2021-10-01 10:10:00  3643.5  3645.0  3635.0  3638.0  3257.0   OZON
# 2021-10-01 10:20:00  3638.0  3647.5  3638.0  3643.5  2640.0   OZON
# 2021-10-01 10:30:00  3646.0  3647.5  3642.0  3642.5   774.0   OZON

# %%
data.isnull().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# Ticker    0
# dtype: int64

# %%
data.describe()
# Out:
#                 Open           High            Low          Close  \
# count  304005.000000  304005.000000  304005.000000  304005.000000
# mean     2424.794058    2429.049807    2420.180416    2424.737511
# std       987.443215     988.422341     986.509129     987.439386
# min       697.500000     698.000000     595.000000     698.000000
# 25%      1559.000000    1561.500000    1555.000000    1559.000000
# 50%      2549.500000    2554.000000    2543.500000    2549.000000
# 75%      3137.000000    3142.000000    3131.000000    3137.000000
# max      4772.500000    4779.500000    4758.500000    4772.500000
#
#               Volume
# count  304005.000000
# mean     6000.714623
# std     11183.595976
# min         1.000000
# 25%       970.000000
# 50%      2536.000000
# 75%      6430.000000
# max    355884.000000

# %% [markdown]
# > Структура данных - OHLC.
#
# > Данные с временным шагом 10 минут.
#
# > За период 01.10.2021 - 02.11.2024.
#
# > Пропуски отсутствуют.

# %% [markdown]
# ## Первичная визуализация

# %%
data['Close'].plot()
plt.title(ticker)
plt.ylabel("Price")
plt.rc("figure", figsize=(25,5))
plt.show()

# %%
plt.style.use("fivethirtyeight")
plt.rcParams['lines.linewidth'] = 1
data.plot(subplots=True, figsize=(25, 25))
# Out:
# array([<Axes: xlabel='Datetime'>, <Axes: xlabel='Datetime'>,
#        <Axes: xlabel='Datetime'>, <Axes: xlabel='Datetime'>,
#        <Axes: xlabel='Datetime'>], dtype=object)

# %%
data['Close'].resample("M").sum().plot()
plt.title('Resampled  - Month')
# Out:
# <ipython-input-12-28a892581506>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data['Close'].resample("M").sum().plot()
# Text(0.5, 1.0, 'Resampled  - Month')

# %%
import statsmodels.api as sm


res = sm.tsa.seasonal_decompose(data['Close'].resample("W").sum())
resplot = res.plot()

# %% [markdown]
# > Сезонности нет.

# %% [markdown]
# ## Статистические характеристики

# %%
X = data['Close'].resample("W").sum()

rolmean = X.rolling(6).mean()
rolstd = X.rolling(6).std()

plt.figure(figsize=(18,6))
orig = plt.plot(X, color='red',label='Original')
mean = plt.plot(rolmean, color='black', label='Rolling Mean')
std = plt.plot(rolstd, color='green', label = 'Rolling Std')
plt.xlabel("Date")
plt.title('Rolling Mean & Standard Deviation')
plt.legend()
plt.show()

# %% [markdown]
# > Нестационарный временной ряд.

# %% [markdown]
# ## Специальные тесты TS

# %% [markdown]
# ADF

# %%
from statsmodels.tsa.stattools import adfuller


X = data['Close'].resample("W").sum().values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# print('Critical Values:')
# for key, value in result[4].items():
# 	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -1.283951
# p-value: 0.636482

# %% [markdown]
# ACF

# %%
from statsmodels.graphics.tsaplots import plot_acf


plot_acf(X)
plt.show()

# %% [markdown]
# PACF

# %%
from statsmodels.graphics.tsaplots import plot_pacf


plot_pacf(X, lags=50)
plt.show()

# %% [markdown]
# ## Дополнительно

# %%
data_2 = data.copy()

# %%
data_2['year'] = [x for x in data_2.index.year]
data_2['month'] = [x for x in data_2.index.month]
data_2 = data_2.reset_index()
data_2['week'] = data_2['Datetime'].apply(lambda x:x.week)
data_2 = data_2.set_index('Datetime')
data_2['hour'] = [x for x in data_2.index.hour]
data_2['day'] = [x for x in data_2.index.day_of_week]
data_2['day_str'] = [x.strftime('%a') for x in data_2.index]
data_2['year_month'] = [str(x.year) + '_' + str(x.month) for x in data_2.index]

# %%
import seaborn as sns


df_plot = data_2[['hour', 'day_str', 'Close']].dropna().groupby(['hour', 'day_str']).mean()[['Close']].reset_index()

plt.figure(figsize=(10,8))
sns.lineplot(data = df_plot, x='hour', y='Close', hue='day_str', legend=True)
plt.locator_params(axis='x', nbins=24)
plt.title("Seasonal Plot - Daily", fontsize=20)
plt.ylabel('Price')
plt.xlabel('Hour')
plt.legend()

# %%
data_2['year'] = [x for x in data_2.index.year]
data_2['month'] = [x for x in data_2.index.month]
data_2['year_month'] = [str(x.year) + '_' + str(x.month) for x in data_2.index]

df_plot = data_2[data_2['year'] >= 2017].reset_index().sort_values(by='Datetime').set_index('Datetime')
plt.title(f'Boxplot Year Month Distribution');
plt.xticks(rotation=90)
plt.xlabel('Year Month')
plt.ylabel('MW')

sns.boxplot(x='year_month', y='Close', data=df_plot)
plt.ylabel('Price')
plt.xlabel('Year Month')
# Out:
# Text(0.5, 0, 'Year Month')
